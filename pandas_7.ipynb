# %%
import pandas as pd

# %%
df = pd.read_csv("http://51.91.120.89/extras/world.csv")
df
# Out:
#      Unnamed: 0      Country  ... Dystopia Residual  Year
# 0             0  Afghanistan  ...          1.952100  2015
# 1             1      Albania  ...          1.898940  2015
# 2             2      Algeria  ...          2.432090  2015
# 3             3       Angola  ...          1.949390  2015
# 4             4    Argentina  ...          2.836000  2015
# ..          ...          ...  ...               ...   ...
# 490         490    Venezuela  ...          1.789464  2017
# 491         491      Vietnam  ...          1.462319  2017
# 492         492        Yemen  ...          1.345601  2017
# 493         493       Zambia  ...          1.826705  2017
# 494         494     Zimbabwe  ...          1.597970  2017
#
# [495 rows x 13 columns]

# %%
df["Year"].unique()
# Out:
# array([2015, 2016, 2017])

# %%
#piwot ze wskaznikiem "Happiness Score" na przestrzeni list
pd.pivot_table(df, index="Year", values="Happiness Score")
# Out:
#       Happiness Score
# Year
# 2015         5.375734
# 2016         5.382185
# 2017         5.354019

# %%
df.query(" Year==2015 ")["Happiness Score"].mean()
# Out:
# 5.375734177215189

# %%
#piwot ze wskaznikiem "Happiness Score" na przestrzeni regionów oraz lat
pd.pivot_table(df, index=["Region", "Year"], values="Happiness Score")

# %%
pd.pivot_table(df, index="Region", values="Happiness Score", columns="Year")
# Out:
# Year                                 2015      2016      2017
# Region
# Australia and New Zealand        7.285000  7.323500  7.299000
# Central and Eastern Europe       5.332931  5.370690  5.409931
# Eastern Asia                     5.626167  5.624167  5.646667
# Latin America and Caribbean      6.144682  6.101750  5.957818
# Middle East and Northern Africa  5.406900  5.386053  5.369684
# North America                    7.273000  7.254000  7.154500
# Southeastern Asia                5.317444  5.338889  5.444875
# Southern Asia                    4.580857  4.563286  4.628429
# Sub-Saharan Africa               4.202800  4.136421  4.111949
# Western Europe                   6.689619  6.685667  6.703714

# %%
df1 = pd.pivot_table(df, index="Region", values=["Happiness Score", "Family"], columns="Year", aggfunc=[min, max])

# %%
df1.columns
# Out:
# MultiIndex([('min',          'Family', 2015),
#             ('min',          'Family', 2016),
#             ('min',          'Family', 2017),
#             ('min', 'Happiness Score', 2015),
#             ('min', 'Happiness Score', 2016),
#             ('min', 'Happiness Score', 2017),
#             ('max',          'Family', 2015),
#             ('max',          'Family', 2016),
#             ('max',          'Family', 2017),
#             ('max', 'Happiness Score', 2015),
#             ('max', 'Happiness Score', 2016),
#             ('max', 'Happiness Score', 2017)],
#            names=[None, None, 'Year'])

# %%
df1[ [('min', 'Family', 2016), ('max', 'Happiness Score', 2017)] ]
# Out:
#                                      min             max
#                                   Family Happiness Score
# Year                                2016            2017
# Region
# Australia and New Zealand        1.10476           7.314
# Central and Eastern Europe       0.19249           6.609
# Eastern Asia                     0.72194           6.422
# Latin America and Caribbean      0.29561           7.079
# Middle East and Northern Africa  0.14866           7.213
# North America                    1.04782           7.316
# Southeastern Asia                0.53750           6.572
# Southern Asia                    0.11037           5.269
# Sub-Saharan Africa               0.00000           5.629
# Western Europe                   0.70697           7.537

# %%
#Szeregi czasowe 
pd.date_range("2022-01-25", "2022-02-28", freq="W")
# Out:
# DatetimeIndex(['2022-01-30', '2022-02-06', '2022-02-13', '2022-02-20',
#                '2022-02-27'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range("2022-01-25", "2022-02-07", freq="2D3H15MIN20S")
# Out:
# DatetimeIndex(['2022-01-25 00:00:00', '2022-01-27 03:15:20',
#                '2022-01-29 06:30:40', '2022-01-31 09:46:00',
#                '2022-02-02 13:01:20', '2022-02-04 16:16:40',
#                '2022-02-06 19:32:00'],
#               dtype='datetime64[ns]', freq='184520S')

# %%
pd.date_range("2022-01-01", "2022-12-31", freq="MS")
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range("2022-01-01",  freq="1H25MIN", periods=10)
# Out:
# DatetimeIndex(['2022-01-01 00:00:00', '2022-01-01 01:25:00',
#                '2022-01-01 02:50:00', '2022-01-01 04:15:00',
#                '2022-01-01 05:40:00', '2022-01-01 07:05:00',
#                '2022-01-01 08:30:00', '2022-01-01 09:55:00',
#                '2022-01-01 11:20:00', '2022-01-01 12:45:00'],
#               dtype='datetime64[ns]', freq='85T')

# %%
url= "https://stooq.pl/q/d/l/?s=tsla.us&d1=20210101&d2=20220125&i=d"
df = pd.read_csv(url, index_col="Data" ,parse_dates=True)
df.head(10)
# Out:
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# Data
# 2021-01-04    719.46   744.4899   717.1895      729.77  48638189
# 2021-01-05    723.66   740.8400   719.2000      735.11  32245165
# 2021-01-06    758.49   774.0000   749.1000      755.98  44699965
# 2021-01-07    777.63   816.9900   775.2000      816.04  51498948
# 2021-01-08    856.00   884.4900   838.3900      880.02  75055528
# 2021-01-11    849.40   854.4300   803.6222      811.19  59554146
# 2021-01-12    831.00   868.0000   827.3400      849.44  46270720
# 2021-01-13    852.76   860.4700   832.0000      854.41  33312496
# 2021-01-14    843.39   863.0000   838.7500      845.00  31266327
# 2021-01-15    852.00   859.9000   819.1000      826.16  38777596

# %%
df.dtypes
# Out:
# Data           object
# Otwarcie      float64
# Najwyzszy     float64
# Najnizszy     float64
# Zamkniecie    float64
# Wolumen         int64
# dtype: object

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14', '2021-01-15',
#                ...
#                '2022-01-10', '2022-01-11', '2022-01-12', '2022-01-13',
#                '2022-01-14', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-24'],
#               dtype='datetime64[ns]', name='Data', length=267, freq=None)

# %%
df.loc["2021-09-01":"2021-09-30"]
# Out:
# Data
# 2021-01-04  719.4600   744.4899   717.1895      729.77  48638189
# 2021-01-05  723.6600   740.8400   719.2000      735.11  32245165
# 2021-01-06  758.4900   774.0000   749.1000      755.98  44699965
# 2021-01-07  777.6300   816.9900   775.2000      816.04  51498948
# 2021-01-08  856.0000   884.4900   838.3900      880.02  75055528
# 2021-01-11  849.4000   854.4300   803.6222      811.19  59554146
# 2021-01-12  831.0000   868.0000   827.3400      849.44  46270720
# 2021-01-13  852.7600   860.4700   832.0000      854.41  33312496
# 2021-01-14  843.3900   863.0000   838.7500      845.00  31266327
# 2021-01-15  852.0000   859.9000   819.1000      826.16  38777596
# 2021-01-19  837.8000   850.0000   833.0000      844.55  25366980
# 2021-01-20  858.7400   859.5000   837.2800      850.45  25665883
# 2021-01-21  855.0000   855.7199   841.4201      844.99  20598133
# ...

# %%
df
# Out:
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# Data
# 2021-01-04   719.460   744.4899   717.1895      729.77  48638189
# 2021-01-05   723.660   740.8400   719.2000      735.11  32245165
# 2021-01-06   758.490   774.0000   749.1000      755.98  44699965
# 2021-01-07   777.630   816.9900   775.2000      816.04  51498948
# 2021-01-08   856.000   884.4900   838.3900      880.02  75055528
# ...              ...        ...        ...         ...       ...
# 2022-01-18  1026.605  1070.7899  1016.0600     1030.51  22329803
# 2022-01-19  1041.705  1054.6699   995.0000      995.65  25147496
# 2022-01-20  1009.730  1041.6600   994.0000      996.27  23496248
# 2022-01-21   996.340  1004.5500   940.5000      943.90  34472009
# 2022-01-24   904.760   933.5131   851.4700      930.00  50791714
#
# [267 rows x 5 columns]

# %%
df1 = df.reset_index()
df1["Data"].apply(lambda x:str(x)[:7])
df1.head()
# Out:
#         Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# 0 2021-01-04    719.46   744.4899   717.1895      729.77  48638189
# 1 2021-01-05    723.66   740.8400   719.2000      735.11  32245165
# 2 2021-01-06    758.49   774.0000   749.1000      755.98  44699965
# 3 2021-01-07    777.63   816.9900   775.2000      816.04  51498948
# 4 2021-01-08    856.00   884.4900   838.3900      880.02  75055528

# %%
df1.groupby("rok_mc")["Zamkniecie"].mean()

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14', '2021-01-15',
#                ...
#                '2022-01-10', '2022-01-11', '2022-01-12', '2022-01-13',
#                '2022-01-14', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-24'],
#               dtype='datetime64[ns]', name='Data', length=267, freq=None)

# %%
df["Zamkniecie"].resample("MS").mean()
# Out:
# Data
# 2021-01-01     828.776842
# 2021-02-01     794.269474
# 2021-03-01     656.802609
# 2021-04-01     709.618095
# 2021-05-01     616.753000
# 2021-06-01     626.919545
# 2021-07-01     659.134762
# 2021-08-01     705.243182
# 2021-09-01     753.952381
# 2021-10-01     878.349048
# 2021-11-01    1120.662381
# 2021-12-01    1018.890000
# 2022-01-01    1049.026000
# Freq: MS, Name: Zamkniecie, dtype: float64

# %%
df["Zamkniecie"].resample("14D").mean()
# Out:
# Data
# 2021-01-04     810.312000
# 2021-01-18     849.293333
# 2021-02-01     841.499000
# 2021-02-15     741.792222
# 2021-03-01     657.543000
# 2021-03-15     661.619000
# 2021-03-29     665.672222
# 2021-04-12     730.199000
# 2021-04-26     688.913000
# 2021-05-10     588.338000
# 2021-05-24     609.693333
# 2021-06-07     608.934000
# 2021-06-21     665.880000
# 2021-07-05     657.381111
# 2021-07-19     656.858000
# 2021-08-02     711.505000
# 2021-08-16     693.367000
# 2021-08-30     740.511111
# 2021-09-13     750.932000
# 2021-09-27     782.490000
# 2021-10-11     847.395000
# 2021-10-25    1131.864000
# 2021-11-08    1074.189000
# 2021-11-22    1104.460000
# 2021-12-06     991.095000
# 2021-12-20    1034.451111
# 2022-01-03    1083.906000
# 2022-01-17     979.266000
# Freq: 14D, Name: Zamkniecie, dtype: float64

# %%
df["Zamkniecie"].resample("Q").max()
# Out:
# Data
# 2021-03-31     883.09
# 2021-06-30     762.32
# 2021-09-30     791.36
# 2021-12-31    1229.91
# 2022-03-31    1199.78
# Freq: Q-DEC, Name: Zamkniecie, dtype: float64

# %%
df["Zamkniecie"].resample("QS").agg([min,max])
# Out:
#                min      max
# Data
# 2021-01-01  563.00   883.09
# 2021-04-01  563.46   762.32
# 2021-07-01  643.38   791.36
# 2021-10-01  775.22  1229.91
# 2022-01-01  930.00  1199.78

# %%
df["Zamkniecie"].plot(figsize=(12,8), grid=True, color="#00FF00")

# %%
df["Zamkniecie"].resample("MS").mean().plot(figsize=(12,8), grid=True, color="#00FF00", kind='bar')

# %%
df
# Out:
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# Data
# 2021-01-04   719.460   744.4899   717.1895      729.77  48638189
# 2021-01-05   723.660   740.8400   719.2000      735.11  32245165
# 2021-01-06   758.490   774.0000   749.1000      755.98  44699965
# 2021-01-07   777.630   816.9900   775.2000      816.04  51498948
# 2021-01-08   856.000   884.4900   838.3900      880.02  75055528
# ...              ...        ...        ...         ...       ...
# 2022-01-18  1026.605  1070.7899  1016.0600     1030.51  22329803
# 2022-01-19  1041.705  1054.6699   995.0000      995.65  25147496
# 2022-01-20  1009.730  1041.6600   994.0000      996.27  23496248
# 2022-01-21   996.340  1004.5500   940.5000      943.90  34472009
# 2022-01-24   904.760   933.5131   851.4700      930.00  50791714
#
# [267 rows x 5 columns]

# %%
df.iloc[:, :4].plot(figsize=(12,8), grid=True)

# %%
#prezentacja średniej kroczącej
chart1=df["Zamkniecie"]
chart1.name = "Kurs. zamk."
chart1.plot(figsize=(12,8), grid=True, legend=True)

chart2 = df[("Zamkniecie")].rolling(20).mean()
chart2.name = "Śr. korcząca"

chart2.rolling(20).mean().plot(figsize=(12,8), grid=True, legend=True)
